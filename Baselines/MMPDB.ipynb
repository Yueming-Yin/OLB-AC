# %% [markdown]
# ### Generate smi files and fragment them by mmpdb

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import rdFMCS
import os, pickle
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import subprocess
import numpy as np

save_output = True
regenerate_smi, refragment, reindex, reproperty, regenerate, reread, recollate, recount, reviz = False, False, False, True, False, False, False, False, False
optimization_task_dict = {'Bioactivity': ['EC50_P21453_1', 'IC50_O43614_1', 'Ki_P14416_1'],
                      'Inhibitory-Efficacy': ['M_C_CYP1A2_inhibitor', 'M_C_CYP2C9_inhibitor', 'M_C_CYP3A4_inhibitor'], 
                      'Toxicity': ['T_C_Ames', 'T_C_NR-AhR', 'T_C_NR-ER']}
train_transformation_dict, mmp_transformation_dict = {}, {}
for optiz_type, task_id_list in optimization_task_dict.items():
    for task_id in tqdm(task_id_list):
        print(f"========================== {task_id} ==========================")
        # Create folder if it doesn't exist
        figures_folder = f'./figures/{task_id}/'
        os.makedirs(figures_folder, exist_ok=True)
        if optiz_type == 'Bioactivity':
            train_filename = f'./OLB-AC-main/LBO-AC-Optimization/{optiz_type}/G_OLB-AC_{task_id}/data/{task_id}_train.csv'
            test_filename = f'./OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_{task_id}/data/{task_id}_test.csv'
            train_df = pd.read_csv(train_filename, header=0, names = ["smiles","value","cano_smiles"],usecols=[1,2,3])
            test_df = pd.read_csv(test_filename,header=0,names=["smiles","value","cano_smiles","matched_smiles","matched_cano_smiles","matched_value"],usecols=[1,2,3,4,5,6])
        else:
            total_filename = f'./OLB-AC-main/LBO-AC-Optimization/{optiz_type}/G_ADMET_{task_id}/data/ADMET/Generation/{task_id}_1.csv'
            total_df = pd.read_csv(total_filename)
            train_df = total_df[total_df['dataset_generate'] == 'training']
            train_df = train_df.reset_index(drop=True)
            train_filename = total_filename.replace(".csv", "_train.csv")
            train_df.to_csv(train_filename, index=False)
            test_df = total_df[total_df['dataset_generate'] == 'test']
            test_df = test_df.reset_index(drop=True)
            test_filename = total_filename.replace(".csv", "_test.csv")
            test_df.to_csv(test_filename, index=False)
        train_df['ID'] = np.arange(len(train_df))
        test_df['ID'] = np.arange(len(test_df))
        train_property_df = train_df[['ID', 'value']]
        train_property_file = train_filename.replace('_train.csv', '_train_properties.csv')
        train_property_df.to_csv(train_property_file, sep='\t', index=False)
        test_property_df = test_df[['ID', 'value']]
        matched_ID = [f'{id}M' for id in test_property_df['ID']]
        matched_values = test_df.matched_value.values
        matched_property_df = test_property_df.copy()
        matched_property_df.loc[:, 'ID'] = matched_ID
        matched_property_df.loc[:, 'value'] = matched_values
        test_merged_property_df = pd.concat([test_property_df, matched_property_df], ignore_index=True)
        test_merged_property_file = test_filename.replace('_test.csv', '_test_properties.csv')
        test_merged_property_df.to_csv(test_merged_property_file, sep='\t', index=False)
        train_smiles = train_df.cano_smiles.values
        test_smiles = test_df.cano_smiles.values
        matched_smiles = test_df.matched_cano_smiles.values
        test_merged_smiles = list(test_smiles) + list(matched_smiles)
        test_merged_ids = test_merged_property_df.ID.values
        test_merged_property = test_merged_property_df.value.values
        print(len(test_merged_ids), len(test_merged_smiles), len(test_merged_property))
    
        # Define the output file paths
        train_smi_file = train_filename.replace('_train.csv', '_train.smi')
        test_smi_file = test_filename.replace('_test.csv', '_test.smi')
        
        # Write smiles to .smi files
        if not os.path.exists(train_smi_file) or regenerate_smi:
            with open(train_smi_file, "w") as f_train:
                for idx, (smile, value) in enumerate(zip(train_df["cano_smiles"], train_df["value"])):
                    f_train.write(f"{smile}\t{idx}\t{value}\n")
        if not os.path.exists(test_smi_file) or regenerate_smi:
            with open(test_smi_file, "w") as f_test:
                for idx, smile, value in zip(test_merged_ids, test_merged_smiles, test_merged_property):
                    f_test.write(f"{smile}\t{idx}\t{value}\n")
                    
        # Fragment smiles to .fragdb files
        train_fragment_file = train_smi_file.replace('.smi', '.fragdb')
        if not os.path.exists(train_fragment_file) or refragment:
            command = f"mmpdb fragment {train_smi_file} -o {train_fragment_file}"
            print(command)
            output = subprocess.run(command, shell=True, capture_output=True, text=True)
            if save_output:
                with open(train_smi_file.replace('.smi', '_fragment_output.txt'), 'w') as f:
                    f.write(output.stderr)
        test_fragment_file = test_smi_file.replace('.smi', '.fragdb')
        if not os.path.exists(test_fragment_file) or refragment:
            command = f"mmpdb fragment {test_smi_file} -o {test_fragment_file}"
            print(command)
            output = subprocess.run(command, shell=True, capture_output=True, text=True)
            if save_output:
                with open(test_smi_file.replace('.smi', '_fragment_output.txt'), 'w') as f:
                    f.write(output.stderr)
    
        # Index to .mmpdb files
        train_index_file = train_fragment_file.replace('.fragdb', '.mmpdb')
        if not os.path.exists(train_index_file) or reindex:
            command = f"mmpdb index {train_fragment_file} -o {train_index_file}"
            print(command)
            output = subprocess.run(command, shell=True, capture_output=True, text=True)
            if save_output:
                with open(train_smi_file.replace('.smi', '_index_output.txt'), 'w') as f:
                    f.write(output.stderr)
        test_index_file = test_fragment_file.replace('.fragdb', '.mmpdb')
        if not os.path.exists(test_index_file) or reindex:
            command = f"mmpdb index {test_fragment_file} -o {test_index_file}"
            print(command)
            output = subprocess.run(command, shell=True, capture_output=True, text=True)
            if save_output:
                with open(test_smi_file.replace('.smi', '_index_output.txt'), 'w') as f:
                    f.write(output.stderr)
            
        # Add properties to the mmpdb databases
        if reproperty:
            command = f"mmpdb loadprops -p {train_property_file} {train_index_file}"
            print(command)
            output = subprocess.run(command, shell=True, capture_output=True, text=True)
            print(output.stderr)
            if save_output:
                with open(train_smi_file.replace('.smi', '_property_output.txt'), 'w') as f:
                    f.write(output.stderr)
        if reproperty:
            command = f"mmpdb loadprops -p {test_merged_property_file} {test_index_file}"
            print(command)
            output = subprocess.run(command, shell=True, capture_output=True, text=True)
            print(output.stderr)
            if save_output:
                with open(test_smi_file.replace('.smi', '_property_output.txt'), 'w') as f:
                    f.write(output.stderr)
    
        # Identify possible transforms and save generated molecules
        for matched_id, matched_smi in zip(matched_ID, matched_smiles):
            save_path = os.path.join(os.path.dirname(test_filename), 'mmpdb', f'{matched_id}.txt')
            if not os.path.exists(os.path.dirname(save_path)):
                os.makedirs(os.path.dirname(save_path))
            if not os.path.exists(save_path) or regenerate:
                command = f"mmpdb transform --smiles '{matched_smi}' {train_index_file} --property value"
                print(command)
                output = subprocess.run(command, shell=True, capture_output=True, text=True)
                # print(output)
                # print(stop)
                if save_output:
                    with open(save_path, 'w') as f:
                        f.write(output.stdout)
            save_csv_path = save_path.replace('.txt', '.csv')
            if not os.path.exists(save_csv_path) or reread:
                try:
                    table_df = pd.read_csv(save_path, sep='\t')
                    table_df.to_csv(save_csv_path, index=False)
                except:
                    print(f"Unable to proceed the molecule {matched_id} in task {task_id}")
    
        for matched_id, matched_smi in zip(test_df.ID.values, test_smiles):
            save_path = os.path.join(os.path.dirname(test_filename), 'mmpdb_reverse', f'{matched_id}.txt')
            if not os.path.exists(os.path.dirname(save_path)):
                os.makedirs(os.path.dirname(save_path))
            if not os.path.exists(save_path) or regenerate:
                command = f"mmpdb transform --smiles '{matched_smi}' {train_index_file} --property value"
                print(command)
                output = subprocess.run(command, shell=True, capture_output=True, text=True)
                if save_output:
                    with open(save_path, 'w') as f:
                        f.write(output.stdout)
            save_csv_path = save_path.replace('.txt', '.csv')
            if not os.path.exists(save_csv_path) or reread:
                try:
                    table_df = pd.read_csv(save_path, sep='\t')
                    table_df.to_csv(save_csv_path, index=False)
                except:
                    print(f"Unable to proceed the molecule {matched_id} in task {task_id}")
    
        # Collate optimized molecules from all generated mmps according to mmp prediciton
        optimized_file = os.path.join(os.path.dirname(test_filename), 'mmpdb', 'optimized.csv')
        reverse_optimized_file = os.path.join(os.path.dirname(test_filename), 'mmpdb_reverse', 'reverse_optimized.csv')
        if not os.path.exists(optimized_file) or recollate:
            column_names = ['smiles', 'mmp_predict', 'value_from_smiles', 'value_to_smiles', 'matched_cano_smiles', 'matched_value', 'matched_id']
            optimized_df = pd.DataFrame(columns=column_names)
            for matched_id, matched_smi, matched_value in zip(matched_ID, matched_smiles, matched_values):
                save_path = os.path.join(os.path.dirname(test_filename), 'mmpdb', f'{matched_id}.csv')
                if os.path.exists(save_path):
                    save_df = pd.read_csv(save_path)
                    for i, row in save_df.iterrows():
                        smiles = row.SMILES
                        mmp_predict = row.value_avg
                        value_from_smiles, value_to_smiles = row.value_from_smiles, row.value_to_smiles # transformations
                        new_data = {'smiles': smiles, 'mmp_predict': mmp_predict, 'value_from_smiles': value_from_smiles, 'value_to_smiles': value_to_smiles, 'matched_cano_smiles': matched_smi, 'matched_value': matched_value, 'matched_id': matched_id}
                        if mmp_predict > 0:
                            optimized_df.loc[len(optimized_df)] = new_data
            optimized_df.to_csv(optimized_file, index=False)
        if not os.path.exists(reverse_optimized_file) or recollate:
            column_names = ['smiles', 'mmp_predict', 'value_from_smiles', 'value_to_smiles', 'matched_cano_smiles', 'matched_value', 'matched_id']
            reverse_optimized_df = pd.DataFrame(columns=column_names)
            for matched_id, matched_smi, matched_value in zip(test_df.ID.values, test_smiles, test_df.value.values):
                save_path = os.path.join(os.path.dirname(test_filename), 'mmpdb_reverse', f'{matched_id}.csv')
                if os.path.exists(save_path):
                    save_df = pd.read_csv(save_path)
                    for i, row in save_df.iterrows():
                        smiles = row.SMILES
                        mmp_predict = row.value_avg
                        value_from_smiles, value_to_smiles = row.value_from_smiles, row.value_to_smiles # transformations
                        new_data = {'smiles': smiles, 'mmp_predict': mmp_predict, 'value_from_smiles': value_from_smiles, 'value_to_smiles': value_to_smiles, 'matched_cano_smiles': matched_smi, 'matched_value': matched_value, 'matched_id': matched_id}
                        if mmp_predict < 0:
                            reverse_optimized_df.loc[len(reverse_optimized_df)] = new_data
            reverse_optimized_df.to_csv(reverse_optimized_file, index=False)
    
        # Visualize transformation distributions
        fig_path = os.path.join(os.path.dirname(test_filename), 'transformations.png')
        if not os.path.exists(fig_path) or reviz:
            # Generate transforamtions in test set
            for matched_id, matched_smi in zip(matched_ID, matched_smiles):
                save_path = os.path.join(os.path.dirname(test_filename), 'mmpdb_test', f'{matched_id}.txt')
                if not os.path.exists(os.path.dirname(save_path)):
                    os.makedirs(os.path.dirname(save_path))
                if not os.path.exists(save_path) or regenerate:
                    command = f"mmpdb transform --smiles '{matched_smi}' {test_index_file} --property value"
                    print(command)
                    output = subprocess.run(command, shell=True, capture_output=True, text=True)
                    if save_output:
                        with open(save_path, 'w') as f:
                            f.write(output.stdout)
                save_csv_path = save_path.replace('.txt', '.csv')
                if not os.path.exists(save_csv_path) or reread:
                    try:
                        table_df = pd.read_csv(save_path, sep='\t')
                        table_df.to_csv(save_csv_path, index=False)
                    except:
                        print(f"Unable to proceed the molecule {matched_id} in task {task_id}")
            # Collate test transformations
            generated_file = os.path.join(os.path.dirname(test_filename), 'mmpdb_test', 'generated.csv')
            if not os.path.exists(generated_file) or recollate:
                column_names = ['smiles', 'mmp_predict', 'value_from_smiles', 'value_to_smiles', 'matched_cano_smiles', 'matched_value', 'matched_id']
                generated_df = pd.DataFrame(columns=column_names)
                for matched_id, matched_smi, matched_value in zip(matched_ID, matched_smiles, matched_values):
                    save_path = os.path.join(os.path.dirname(test_filename), 'mmpdb_test', f'{matched_id}.csv')
                    if os.path.exists(save_path):
                        save_df = pd.read_csv(save_path)
                        for i, row in save_df.iterrows():
                            smiles = row.SMILES
                            mmp_predict = row.value_avg
                            value_from_smiles, value_to_smiles = row.value_from_smiles, row.value_to_smiles # transformations
                            new_data = {'smiles': smiles, 'mmp_predict': mmp_predict, 'value_from_smiles': value_from_smiles, 'value_to_smiles': value_to_smiles, 'matched_cano_smiles': matched_smi, 'matched_value': matched_value, 'matched_id': matched_id}
                            generated_df.loc[len(generated_df)] = new_data
                generated_df.to_csv(generated_file, index=False)
            # Visualize transformations between training and test set
            train_count_file = os.path.join(os.path.dirname(test_filename), 'mmpdb', 'train_transformations.pkl')
            test_count_file = os.path.join(os.path.dirname(test_filename), 'mmpdb', 'test_transformations.pkl')
            overlap_count_file = os.path.join(os.path.dirname(test_filename), 'mmpdb', 'overlapped_transformations.pkl')
            if not os.path.exists(train_count_file) or not os.path.exists(test_count_file) or not os.path.exists(overlap_count_file) or recount:
                optimized_df, reverse_optimized_df = pd.read_csv(optimized_file), pd.read_csv(reverse_optimized_file)
                train_transformations_optimized = [f'{before}>>{after}' for before, after in zip(optimized_df.value_from_smiles.values, optimized_df.value_to_smiles.values)]
                train_transformations_reverse_optimized = [f'{before}>>{after}' for before, after in zip(reverse_optimized_df.value_from_smiles.values, reverse_optimized_df.value_to_smiles.values)]
                train_transformations = train_transformations_optimized + train_transformations_reverse_optimized
                generated_df = pd.read_csv(generated_file)
                test_transformations = [f'{before}>>{after}' for before, after in zip(generated_df.value_from_smiles.values, generated_df.value_to_smiles.values)]
                # Calculate counts for each transformation
                all_transformations = set(train_transformations).union(test_transformations)
                train_count = {trans: train_transformations.count(trans) for trans in all_transformations}
                test_count = {trans: test_transformations.count(trans) for trans in all_transformations}
                overlapping_counts = {trans: min(train_count[trans], test_count[trans]) for trans in all_transformations}
                with open(train_count_file, 'wb') as f:
                    pickle.dump(train_count, f)
                with open(test_count_file, 'wb') as f:
                    pickle.dump(test_count, f)
                with open(overlap_count_file, 'wb') as f:
                    pickle.dump(overlapping_counts, f)
            else:
                with open(train_count_file, 'rb') as f:
                    train_count = pickle.load(f)
                with open(test_count_file, 'rb') as f:
                    test_count = pickle.load(f)
                with open(overlap_count_file, 'rb') as f:
                    overlapping_counts = pickle.load(f)
            
            # Calculate total counts
            # total_train = sum(train_count.values())
            # total_test = sum(test_count.values())
            # total_overlap = sum(overlapping_counts.values())
            total_train, total_test, total_overlap = 0, 0, 0
            for key, value in train_count.items():
                if value > 0:
                    total_train += 1
            for key, value in test_count.items():
                if value > 0:
                    total_test += 1
            for key, value in overlapping_counts.items():
                if value > 0:
                    total_overlap += 1
            
            # Calculate percentages
            train_percentage = total_train / (total_train + total_test + total_overlap) * 100
            test_percentage = total_test / (total_train + total_test + total_overlap) * 100
            overlap_percentage = total_overlap / (total_train + total_test + total_overlap) * 100
            print(f"Task: {task_id}\ntrain_percentage: {train_percentage:.2f}%\ntest_percentage: {test_percentage:.2f}%\noverlap_percentage: {overlap_percentage:.2f}%")
            print(f"------------------------------------------------")
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ========================== EC50_P21453_1 ==========================
# 196 196 196
# mmpdb loadprops -p ./OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_EC50_P21453_1/data/EC50_P21453_1_train_properties.csv ./OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_EC50_P21453_1/data/EC50_P21453_1_train.mmpdb
# Using dataset: MMPs from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_EC50_P21453_1/data/EC50_P21453_1_train.fragdb'
# Reading properties from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_EC50_P21453_1/data/EC50_P21453_1_train_properties.csv'
# Read 1 properties for 2860 compounds from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_EC50_P21453_1/data/EC50_P21453_1_train_properties.csv'
# 785 compounds from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_EC50_P21453_1/data/EC50_P21453_1_train_properties.csv' are not in the dataset at './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_EC50_P21453_1/data/EC50_P21453_1_train.mmpdb'
# Imported 2075 'value' records (0 new, 2075 updated).
# Computing aggregate statistics
#
# Computing aggregate statistics 0/405510 (0.0%)
#
# Computing aggregate statistics 18040/405510 (4.4%)
#
# Computing aggregate statistics 46800/405510 (11.5%)
#
# Computing aggregate statistics 64678/405510 (15.9%)
#
# Computing aggregate statistics 86783/405510 (21.4%)
#
# Computing aggregate statistics 124858/405510 (30.8%)
#
# Computing aggregate statistics 153966/405510 (38.0%)
#
# Computing aggregate statistics 174929/405510 (43.1%)
#
# Computing aggregate statistics 197346/405510 (48.7%)
#
# Computing aggregate statistics 217904/405510 (53.7%)
#
# Computing aggregate statistics 242500/405510 (59.8%)
#
# Computing aggregate statistics 267593/405510 (66.0%)
#
# Computing aggregate statistics 290494/405510 (71.6%)
#
# Computing aggregate statistics 322038/405510 (79.4%)
#
# Computing aggregate statistics 344210/405510 (84.9%)
#
# Computing aggregate statistics 372530/405510 (91.9%)
#
# Computing aggregate statistics 399905/405510 (98.6%)
#
#
#
# Generated 259236 rule statistics (259236 rule environments, 1 properties)
#
#
# Getting information about which rule statistics exist...
#
# Updating statistics table 0/259236 (0.0%)
#
# Updating statistics table 78756/259236 (30.4%)
#
# Updating statistics table 157286/259236 (60.7%)
#
# Updating statistics table 223513/259236 (86.2%)
#
#
#
# Number of rule statistics added: 0 updated: 259236 deleted: 0
#
#
# Updating environment statistics count ...
#
# Commiting changed ...
#
# Loaded all properties and re-computed all rule statistics.
#
# mmpdb loadprops -p ./OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_EC50_P21453_1/data/EC50_P21453_1_test_properties.csv ./OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_EC50_P21453_1/data/EC50_P21453_1_test.mmpdb
# Using dataset: MMPs from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_EC50_P21453_1/data/EC50_P21453_1_test.fragdb'
# Reading properties from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_EC50_P21453_1/data/EC50_P21453_1_test_properties.csv'
# Read 1 properties for 196 compounds from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_EC50_P21453_1/data/EC50_P21453_1_test_properties.csv'
# 21 compounds from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_EC50_P21453_1/data/EC50_P21453_1_test_properties.csv' are not in the dataset at './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_EC50_P21453_1/data/EC50_P21453_1_test.mmpdb'
# Imported 175 'value' records (0 new, 175 updated).
# Computing aggregate statistics
#
# Computing aggregate statistics 0/7620 (0.0%)
#
#
#
# Generated 5636 rule statistics (5636 rule environments, 1 properties)
#
#
# Getting information about which rule statistics exist...
#
# Updating statistics table 0/5636 (0.0%)
#
#
#
# Number of rule statistics added: 0 updated: 5636 deleted: 0
#
#
# Updating environment statistics count ...
#
# Commiting changed ...
#
# Loaded all properties and re-computed all rule statistics.
#
# Unable to proceed the molecule 6M in task EC50_P21453_1
# Unable to proceed the molecule 21M in task EC50_P21453_1
# Unable to proceed the molecule 34M in task EC50_P21453_1
# Unable to proceed the molecule 35M in task EC50_P21453_1
# Unable to proceed the molecule 57M in task EC50_P21453_1
# Unable to proceed the molecule 91M in task EC50_P21453_1
# Unable to proceed the molecule 6 in task EC50_P21453_1
# Unable to proceed the molecule 21 in task EC50_P21453_1
# Unable to proceed the molecule 34 in task EC50_P21453_1
# Unable to proceed the molecule 35 in task EC50_P21453_1
# Unable to proceed the molecule 91 in task EC50_P21453_1
# ========================== IC50_O43614_1 ==========================
# 162 162 162
# mmpdb loadprops -p ./OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_IC50_O43614_1/data/IC50_O43614_1_train_properties.csv ./OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_IC50_O43614_1/data/IC50_O43614_1_train.mmpdb
# Using dataset: MMPs from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_IC50_O43614_1/data/IC50_O43614_1_train.fragdb'
# Reading properties from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_IC50_O43614_1/data/IC50_O43614_1_train_properties.csv'
# Read 1 properties for 2619 compounds from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_IC50_O43614_1/data/IC50_O43614_1_train_properties.csv'
# 255 compounds from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_IC50_O43614_1/data/IC50_O43614_1_train_properties.csv' are not in the dataset at './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_IC50_O43614_1/data/IC50_O43614_1_train.mmpdb'
# Imported 2364 'value' records (0 new, 2364 updated).
# Computing aggregate statistics
#
# Computing aggregate statistics 0/263514 (0.0%)
#
# Computing aggregate statistics 22152/263514 (8.4%)
#
# Computing aggregate statistics 38934/263514 (14.8%)
#
# Computing aggregate statistics 57635/263514 (21.9%)
#
# Computing aggregate statistics 76147/263514 (28.9%)
#
# Computing aggregate statistics 108551/263514 (41.2%)
#
# Computing aggregate statistics 127305/263514 (48.3%)
#
# Computing aggregate statistics 150186/263514 (57.0%)
#
# Computing aggregate statistics 173491/263514 (65.8%)
#
# Computing aggregate statistics 196171/263514 (74.4%)
#
# Computing aggregate statistics 221538/263514 (84.1%)
#
# Computing aggregate statistics 242005/263514 (91.8%)
#
#
#
# Generated 154156 rule statistics (154156 rule environments, 1 properties)
#
#
# Getting information about which rule statistics exist...
#
# Updating statistics table 0/154156 (0.0%)
#
# Updating statistics table 82140/154156 (53.3%)
#
#
#
# Number of rule statistics added: 0 updated: 154156 deleted: 0
#
#
# Updating environment statistics count ...
#
# Commiting changed ...
#
# Loaded all properties and re-computed all rule statistics.
#
# mmpdb loadprops -p ./OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_IC50_O43614_1/data/IC50_O43614_1_test_properties.csv ./OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_IC50_O43614_1/data/IC50_O43614_1_test.mmpdb
# Using dataset: MMPs from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_IC50_O43614_1/data/IC50_O43614_1_test.fragdb'
# Reading properties from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_IC50_O43614_1/data/IC50_O43614_1_test_properties.csv'
# Read 1 properties for 162 compounds from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_IC50_O43614_1/data/IC50_O43614_1_test_properties.csv'
# 2 compounds from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_IC50_O43614_1/data/IC50_O43614_1_test_properties.csv' are not in the dataset at './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_IC50_O43614_1/data/IC50_O43614_1_test.mmpdb'
# Imported 160 'value' records (0 new, 160 updated).
# Computing aggregate statistics
#
# Computing aggregate statistics 0/6360 (0.0%)
#
#
#
# Generated 4383 rule statistics (4383 rule environments, 1 properties)
#
#
# Getting information about which rule statistics exist...
#
# Updating statistics table 0/4383 (0.0%)
#
#
#
# Number of rule statistics added: 0 updated: 4383 deleted: 0
#
#
# Updating environment statistics count ...
#
# Commiting changed ...
#
# Loaded all properties and re-computed all rule statistics.
#
# Unable to proceed the molecule 63M in task IC50_O43614_1
# Unable to proceed the molecule 63 in task IC50_O43614_1
# ========================== Ki_P14416_1 ==========================
# 354 354 354
# mmpdb loadprops -p ./OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_Ki_P14416_1/data/Ki_P14416_1_train_properties.csv ./OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_Ki_P14416_1/data/Ki_P14416_1_train.mmpdb
# Using dataset: MMPs from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_Ki_P14416_1/data/Ki_P14416_1_train.fragdb'
# Reading properties from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_Ki_P14416_1/data/Ki_P14416_1_train_properties.csv'
# Read 1 properties for 6440 compounds from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_Ki_P14416_1/data/Ki_P14416_1_train_properties.csv'
# 923 compounds from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_Ki_P14416_1/data/Ki_P14416_1_train_properties.csv' are not in the dataset at './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_Ki_P14416_1/data/Ki_P14416_1_train.mmpdb'
# Imported 5517 'value' records (0 new, 5517 updated).
# Computing aggregate statistics
#
# Computing aggregate statistics 0/365394 (0.0%)
#
# Computing aggregate statistics 22084/365394 (6.0%)
#
# Computing aggregate statistics 58683/365394 (16.1%)
#
# Computing aggregate statistics 84813/365394 (23.2%)
#
# Computing aggregate statistics 110660/365394 (30.3%)
#
# Computing aggregate statistics 130636/365394 (35.8%)
#
# Computing aggregate statistics 157924/365394 (43.2%)
#
# Computing aggregate statistics 184656/365394 (50.5%)
#
# Computing aggregate statistics 206234/365394 (56.4%)
#
# Computing aggregate statistics 228922/365394 (62.7%)
#
# Computing aggregate statistics 253596/365394 (69.4%)
#
# Computing aggregate statistics 278672/365394 (76.3%)
#
# Computing aggregate statistics 306688/365394 (83.9%)
#
# Computing aggregate statistics 331447/365394 (90.7%)
#
# Computing aggregate statistics 356180/365394 (97.5%)
#
#
#
# Generated 192473 rule statistics (192473 rule environments, 1 properties)
#
#
# Getting information about which rule statistics exist...
#
# Updating statistics table 0/192473 (0.0%)
#
# Updating statistics table 84724/192473 (44.0%)
#
# Updating statistics table 165795/192473 (86.1%)
#
#
#
# Number of rule statistics added: 0 updated: 192473 deleted: 0
#
#
# Updating environment statistics count ...
#
# Commiting changed ...
#
# Loaded all properties and re-computed all rule statistics.
#
# mmpdb loadprops -p ./OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_Ki_P14416_1/data/Ki_P14416_1_test_properties.csv ./OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_Ki_P14416_1/data/Ki_P14416_1_test.mmpdb
# Using dataset: MMPs from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_Ki_P14416_1/data/Ki_P14416_1_test.fragdb'
# Reading properties from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_Ki_P14416_1/data/Ki_P14416_1_test_properties.csv'
# Read 1 properties for 354 compounds from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_Ki_P14416_1/data/Ki_P14416_1_test_properties.csv'
# 26 compounds from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_Ki_P14416_1/data/Ki_P14416_1_test_properties.csv' are not in the dataset at './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_Ki_P14416_1/data/Ki_P14416_1_test.mmpdb'
# Imported 328 'value' records (0 new, 328 updated).
# Computing aggregate statistics
#
# Computing aggregate statistics 0/8922 (0.0%)
#
#
#
# Generated 4149 rule statistics (4149 rule environments, 1 properties)
#
#
# Getting information about which rule statistics exist...
#
# Updating statistics table 0/4149 (0.0%)
#
#
#
# Number of rule statistics added: 0 updated: 4149 deleted: 0
#
#
# Updating environment statistics count ...
#
# Commiting changed ...
#
# Loaded all properties and re-computed all rule statistics.
#
# Unable to proceed the molecule 59M in task Ki_P14416_1
# Unable to proceed the molecule 109M in task Ki_P14416_1
# Unable to proceed the molecule 147M in task Ki_P14416_1
# Unable to proceed the molecule 59 in task Ki_P14416_1
# Unable to proceed the molecule 109 in task Ki_P14416_1
# Unable to proceed the molecule 147 in task Ki_P14416_1
#   0%|          | 0/3 [00:00<?, ?it/s]
# ========================== M_C_CYP1A2_inhibitor ==========================
# 60 60 60
# mmpdb loadprops -p ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train_properties.csv ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb
# Using dataset: MMPs from './OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.fragdb'
# Reading properties from './OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train_properties.csv'
# Read 1 properties for 11343 compounds from './OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train_properties.csv'
# 4257 compounds from './OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train_properties.csv' are not in the dataset at './OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb'
# Imported 7086 'value' records (0 new, 7086 updated).
# Computing aggregate statistics
#
# Computing aggregate statistics 0/809892 (0.0%)
#
# Computing aggregate statistics 87501/809892 (10.8%)
#
# Computing aggregate statistics 168023/809892 (20.7%)
#
# Computing aggregate statistics 256848/809892 (31.7%)
#
# Computing aggregate statistics 339944/809892 (42.0%)
#
# Computing aggregate statistics 414640/809892 (51.2%)
#
# Computing aggregate statistics 488108/809892 (60.3%)
#
# Computing aggregate statistics 583652/809892 (72.1%)
#
# Computing aggregate statistics 657823/809892 (81.2%)
#
# Computing aggregate statistics 746237/809892 (92.1%)
#
#
#
# Generated 675750 rule statistics (675750 rule environments, 1 properties)
#
#
# Getting information about which rule statistics exist...
#
# Updating statistics table 0/675750 (0.0%)
#
# Updating statistics table 81239/675750 (12.0%)
#
# Updating statistics table 163230/675750 (24.2%)
#
# Updating statistics table 230019/675750 (34.0%)
#
# Updating statistics table 311473/675750 (46.1%)
#
# Updating statistics table 380135/675750 (56.3%)
#
# Updating statistics table 462160/675750 (68.4%)
#
# Updating statistics table 531902/675750 (78.7%)
#
# Updating statistics table 612626/675750 (90.7%)
#
#
#
# Number of rule statistics added: 0 updated: 675750 deleted: 0
#
#
# Updating environment statistics count ...
#
# Commiting changed ...
#
# Loaded all properties and re-computed all rule statistics.
#
# mmpdb loadprops -p ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test_properties.csv ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb
# Using dataset: MMPs from './OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.fragdb'
# Reading properties from './OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test_properties.csv'
# Read 1 properties for 60 compounds from './OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test_properties.csv'
# 2 compounds from './OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test_properties.csv' are not in the dataset at './OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb'
# Imported 58 'value' records (0 new, 58 updated).
# Computing aggregate statistics
#
# Computing aggregate statistics 0/552 (0.0%)
#
#
#
# Generated 331 rule statistics (331 rule environments, 1 properties)
#
#
# Getting information about which rule statistics exist...
#
# Updating statistics table 0/331 (0.0%)
#
#
#
# Number of rule statistics added: 0 updated: 331 deleted: 0
#
#
# Updating environment statistics count ...
#
# Commiting changed ...
#
# Loaded all properties and re-computed all rule statistics.
#
# mmpdb transform --smiles 'O=c1c(-c2ccc(F)cc2)nc2cnc(Nc3ccccc3)nc2n1C1CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'COC(=O)N1CCCC2(CCN(c3ncccn3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1cccc(F)c1)N1CCC2(CC1)CCN(c1ccccn1)CC2' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(NCC1CCCO1)C(c1cccnc1)N(C(=O)Cc1cccs1)c1cccnc1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'CC(CCc1ccccc1)NC(=O)C(=O)NCCO' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'Cc1cc(=O)oc(C)c1C(=O)NCc1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1csnn1)N1CCCC2(CCN(c3ccccn3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'CN1CCN(CC(=O)N2c3ccccc3Sc3cc4ccccc4cc32)CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=S(=O)(c1ccccc1)N1CCC2(CCCN(Cc3ccccc3)C2)CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(Oc1ccccc1)N1CCCC2(CCN(c3ccccc3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1ccco1)N1CCC2(CC1)CCN(c1ccccc1)CC2' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'Cc1cc(=O)oc(C)c1C(=O)NCc1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1cnccn1)N1CCCC2(CCN(Cc3ccccc3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1ccco1)N1CCCC2(CCN(Cc3ccccc3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'COCCn1c(=O)c(-c2ccc(OC)cc2)nc2cnc(Nc3ccccc3)nc21' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1cccc(F)c1)N1CCCC2(CCN(c3ccccc3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1ccncc1)N1CCC2(CCCN(c3ccncc3)C2)CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=S(=O)(c1ccccc1)N1CCCC2(CCN(c3ccncc3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'COc1ccc(C(=O)N2CCCC3(CCN(c4ccncc4)C3)C2)cc1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=c1c(-c2cc(F)cc(F)c2)nc2cnc(N3CCOCC3)nc2n1Cc1ccc(F)cc1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'COCC(=O)N1CCC2(CCN(Cc3ccccc3)CC2)CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=c1c(-c2ccc(Cl)cc2)nc2cnc(Nc3ccccc3)nc2n1C1CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=c1c(-c2cc(F)cc(F)c2)nc2cnc(Nc3ccccc3)nc2n1CC1CCCO1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'CN(C)CCC=C1c2ccccc2CSc2ccccc21' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1ccncc1)N1CCC2(CCCN(Cc3ccccc3)C2)CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1csnn1)N1CCCC2(CCN(Cc3ccccc3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=S(=O)(O)c1nc2ccccc2n1Cc1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=c1c(-c2ccc(F)cc2)nc2cnc(N3CCOCC3)nc2n1C1CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'COc1cccc(C2=NOC(C(=O)NCc3ccccn3)C2)c1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'COc1ccc(-c2nc3cnc(N4CCOCC4)nc3n(-c3ccccc3)c2=O)cc1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=c1c(-c2ccc(F)cc2)nc2cnc(Oc3ccccc3)nc2n1C1CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'COC(=O)N1CCCC2(CCN(c3ccccn3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1cccc(F)c1)N1CCC2(CC1)CCN(c1ccccc1)CC2' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(NCC1CCCO1)C(c1cccnc1)N(C(=O)Cc1cccs1)c1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'CCCCNC(=O)C(=O)NC(C)CCc1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'Cc1cc(=O)oc(C)c1C(=O)NCc1ccccn1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1csnn1)N1CCCC2(CCN(c3ccccc3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'CC1CCN(CC(=O)N2c3ccccc3Sc3cc4ccccc4cc32)CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=S(=O)(c1ccccc1)N1CCC2(CCCN(Cc3ccncc3)C2)CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(Oc1ccccc1)N1CCCC2(CCN(c3ccccn3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1ccco1)N1CCC2(CC1)CCN(c1ccncc1)CC2' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'Cc1cc(=O)oc(C)c1C(=O)NCc1cccnc1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1cnccn1)N1CCCC2(CCN(Cc3ccncc3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1ccco1)N1CCCC2(CCN(Cc3ccncc3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'COCCn1c(=O)c(-c2ccc(OC)cc2)nc2cnc(Oc3ccccc3)nc21' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1cccc(F)c1)N1CCCC2(CCN(c3ccccn3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1ccncc1)N1CCC2(CCCN(c3ccccc3)C2)CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=S(=O)(c1ccccc1)N1CCCC2(CCN(c3ccccc3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'COc1ccc(C(=O)N2CCCC3(CCN(c4ccccc4)C3)C2)cc1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=c1c(-c2cc(F)cc(F)c2)nc2cnc(N3CCNCC3)nc2n1Cc1ccc(F)cc1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'COCC(=O)N1CCC2(CCN(Cc3ccncc3)CC2)CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=c1c(-c2ccc(Cl)cc2)nc2cnc(Oc3ccccc3)nc2n1C1CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=c1c(-c2cc(F)cc(F)c2)nc2cnc(Oc3ccccc3)nc2n1CC1CCCO1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'CN(C)CCC=C1c2ccccc2COc2ccccc21' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1ccncc1)N1CCC2(CCCN(Cc3ccncc3)C2)CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1csnn1)N1CCCC2(CCN(Cc3ccncc3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'CS(=O)(=O)c1nc2ccccc2n1Cc1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=c1c(-c2ccc(F)cc2)nc2cnc(N3CCNCC3)nc2n1C1CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'COc1cccc(C2=NOC(C(=O)NCc3ccccc3)C2)c1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'COc1ccc(-c2nc3cnc(N4CCNCC4)nc3n(-c3ccccc3)c2=O)cc1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=c1c(-c2ccc(F)cc2)nc2cnc(Nc3ccccc3)nc2n1C1CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'COC(=O)N1CCCC2(CCN(c3ncccn3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1cccc(F)c1)N1CCC2(CC1)CCN(c1ccccn1)CC2' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=C(NCC1CCCO1)C(c1cccnc1)N(C(=O)Cc1cccs1)c1cccnc1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'CC(CCc1ccccc1)NC(=O)C(=O)NCCO' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'Cc1cc(=O)oc(C)c1C(=O)NCc1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1csnn1)N1CCCC2(CCN(c3ccccn3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'CN1CCN(CC(=O)N2c3ccccc3Sc3cc4ccccc4cc32)CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=S(=O)(c1ccccc1)N1CCC2(CCCN(Cc3ccccc3)C2)CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=C(Oc1ccccc1)N1CCCC2(CCN(c3ccccc3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1ccco1)N1CCC2(CC1)CCN(c1ccccc1)CC2' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'Cc1cc(=O)oc(C)c1C(=O)NCc1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1cnccn1)N1CCCC2(CCN(Cc3ccccc3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1ccco1)N1CCCC2(CCN(Cc3ccccc3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'COCCn1c(=O)c(-c2ccc(OC)cc2)nc2cnc(Nc3ccccc3)nc21' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1cccc(F)c1)N1CCCC2(CCN(c3ccccc3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1ccncc1)N1CCC2(CCCN(c3ccncc3)C2)CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=S(=O)(c1ccccc1)N1CCCC2(CCN(c3ccncc3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'COc1ccc(C(=O)N2CCCC3(CCN(c4ccncc4)C3)C2)cc1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=c1c(-c2cc(F)cc(F)c2)nc2cnc(N3CCOCC3)nc2n1Cc1ccc(F)cc1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'COCC(=O)N1CCC2(CCN(Cc3ccccc3)CC2)CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=c1c(-c2ccc(Cl)cc2)nc2cnc(Nc3ccccc3)nc2n1C1CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=c1c(-c2cc(F)cc(F)c2)nc2cnc(Nc3ccccc3)nc2n1CC1CCCO1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'CN(C)CCC=C1c2ccccc2CSc2ccccc21' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1ccncc1)N1CCC2(CCCN(Cc3ccccc3)C2)CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=C(c1csnn1)N1CCCC2(CCN(Cc3ccccc3)C2)C1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=S(=O)(O)c1nc2ccccc2n1Cc1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=c1c(-c2ccc(F)cc2)nc2cnc(N3CCOCC3)nc2n1C1CC1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'COc1cccc(C2=NOC(C(=O)NCc3ccccn3)C2)c1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# mmpdb transform --smiles 'COc1ccc(-c2nc3cnc(N4CCOCC4)nc3n(-c3ccccc3)c2=O)cc1' ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP1A2_inhibitor/data/ADMET/Generation/M_C_CYP1A2_inhibitor_1_test.mmpdb --property value
# Task: M_C_CYP1A2_inhibitor
# train_percentage: 90.97%
# test_percentage: 6.25%
# overlap_percentage: 2.78%
# ------------------------------------------------
# ========================== M_C_CYP2C9_inhibitor ==========================
# 146 146 146
# mmpdb fragment ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP2C9_inhibitor/data/ADMET/Generation/M_C_CYP2C9_inhibitor_1_train.smi -o ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP2C9_inhibitor/data/ADMET/Generation/M_C_CYP2C9_inhibitor_1_train.fragdb
# mmpdb fragment ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP2C9_inhibitor/data/ADMET/Generation/M_C_CYP2C9_inhibitor_1_test.smi -o ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP2C9_inhibitor/data/ADMET/Generation/M_C_CYP2C9_inhibitor_1_test.fragdb
# mmpdb index ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP2C9_inhibitor/data/ADMET/Generation/M_C_CYP2C9_inhibitor_1_train.fragdb -o ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP2C9_inhibitor/data/ADMET/Generation/M_C_CYP2C9_inhibitor_1_train.mmpdb
# mmpdb index ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP2C9_inhibitor/data/ADMET/Generation/M_C_CYP2C9_inhibitor_1_test.fragdb -o ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP2C9_inhibitor/data/ADMET/Generation/M_C_CYP2C9_inhibitor_1_test.mmpdb
# mmpdb loadprops -p ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP2C9_inhibitor/data/ADMET/Generation/M_C_CYP2C9_inhibitor_1_train_properties.csv ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP2C9_inhibitor/data/ADMET/Generation/M_C_CYP2C9_inhibitor_1_train.mmpdb
# Using dataset: MMPs from './OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP2C9_inhibitor/data/ADMET/Generation/M_C_CYP2C9_inhibitor_1_train.fragdb'
# Reading properties from './OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP2C9_inhibitor/data/ADMET/Generation/M_C_CYP2C9_inhibitor_1_train_properties.csv'
# Read 1 properties for 10836 compounds from './OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP2C9_inhibitor/data/ADMET/Generation/M_C_CYP2C9_inhibitor_1_train_properties.csv'
# 4244 compounds from './OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP2C9_inhibitor/data/ADMET/Generation/M_C_CYP2C9_inhibitor_1_train_properties.csv' are not in the dataset at './OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP2C9_inhibitor/data/ADMET/Generation/M_C_CYP2C9_inhibitor_1_train.mmpdb'
# Imported 6592 'value' records (6592 new, 0 updated).
# Computing aggregate statistics
#
# Computing aggregate statistics 0/949374 (0.0%)
#
# Computing aggregate statistics 86775/949374 (9.1%)
#
# Computing aggregate statistics 174930/949374 (18.4%)
#
# Computing aggregate statistics 264655/949374 (27.9%)
#
# Computing aggregate statistics 349089/949374 (36.8%)
#
# Computing aggregate statistics 427439/949374 (45.0%)
#
# Computing aggregate statistics 502848/949374 (53.0%)
#
# Computing aggregate statistics 593571/949374 (62.5%)
#
# Computing aggregate statistics 654018/949374 (68.9%)
#
# Computing aggregate statistics 737638/949374 (77.7%)
#
# Computing aggregate statistics 818381/949374 (86.2%)
#
# Computing aggregate statistics 875803/949374 (92.3%)
#
# Computing aggregate statistics 940848/949374 (99.1%)
#
#
#
# Generated 823194 rule statistics (823194 rule environments, 1 properties)
#
#
# Getting information about which rule statistics exist...
#
# Updating statistics table 0/823194 (0.0%)
#
# Updating statistics table 77966/823194 (9.5%)
#
# Updating statistics table 160673/823194 (19.5%)
#
# Updating statistics table 243259/823194 (29.6%)
#
# Updating statistics table 324458/823194 (39.4%)
#
# Updating statistics table 406006/823194 (49.3%)
#
# Updating statistics table 487793/823194 (59.3%)
#
# Updating statistics table 570098/823194 (69.3%)
#
# Updating statistics table 651825/823194 (79.2%)
#
# Updating statistics table 733197/823194 (89.1%)
#
# Updating statistics table 814054/823194 (98.9%)
#
#
#
# Number of rule statistics added: 823194 updated: 0 deleted: 0
#
#
# Updating environment statistics count ...
#
# Commiting changed ...
#
# Loaded all properties and re-computed all rule statistics.
#
# mmpdb loadprops -p ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP2C9_inhibitor/data/ADMET/Generation/M_C_CYP2C9_inhibitor_1_test_properties.csv ./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP2C9_inhibitor/data/ADMET/Generation/M_C_CYP2C9_inhibitor_1_test.mmpdb
# Using dataset: MMPs from './OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_M_C_CYP2C9_inhibitor/data/ADMET/Generation/M_C_CYP2C9_inhibitor_1_test.fragdb'
# ...
# mmpdb transform --smiles 'O=[N+]([O-])c1ccccc1O' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_train.mmpdb --property value
# mmpdb transform --smiles 'CC(C)CC(=O)O' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_train.mmpdb --property value
# mmpdb transform --smiles 'S=C(Nc1ccccc1)Nc1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_train.mmpdb --property value
# mmpdb transform --smiles 'CNC(=O)c1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_train.mmpdb --property value
# mmpdb transform --smiles 'O=C(NO)c1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_train.mmpdb --property value
# mmpdb transform --smiles 'CCCCOCCOC(C)=O' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_train.mmpdb --property value
# mmpdb transform --smiles 'CN(N=O)c1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_train.mmpdb --property value
# mmpdb transform --smiles 'NC(=O)CCCCC1CCSS1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CCCCc1ccc2[nH]c(NC(=O)OC)nc2c1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CN1CCN(c2c(F)cc3c(=O)c(C(=O)O)cn4c3c2OCN4C)CC1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CCNCCO' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'NC(=O)C(Cl)(Cl)Cl' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'C=CCCl' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'Oc1cccc(O)c1O' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'Oc1cccc(O)c1O' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CCCC(=O)CC' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'SCc1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'N[C@H]1C(O)O[C@H](CO)[C@@H](O)[C@@H]1O' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'C[C@]12C[C@H](O)[C@@]3(F)[C@@H](CCC4=CC(=O)C=C[C@@]43C)[C@@H]1C[C@@H](O)[C@]2(O)C(=O)CO' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CC1CCC(C(C)C)C(OC(=O)c2ccccc2N)C1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CCCCCCCCCCCCCCNCCO' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# Unable to proceed the molecule 13M in task T_C_NR-ER
# mmpdb transform --smiles 'CCCCCCCCCCCCCCNCCO' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# Unable to proceed the molecule 14M in task T_C_NR-ER
# mmpdb transform --smiles 'CCOC(=O)c1ccc(O)cc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CC(O)CN(C)C' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'OCC=Cc1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'NC[C@@H]1O[C@H](O[C@@H]2[C@@H](CO)O[C@@H](O[C@@H]3[C@@H](O)[C@H](N)C[C@H](N)[C@H]3O[C@H]3O[C@H](CO)[C@@H](O)[C@H](O)[C@H]3N)[C@@H]2O)[C@H](N)[C@@H](O)[C@@H]1O' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'NNC(=O)c1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=[N+]([O-])c1cccc(O)c1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=[N+]([O-])c1cccc(O)c1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'Cc1ccc(N)cc1C' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'SCc1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'Oc1ccc2ccc3cccc4ccc1c2c34' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CCNCCO' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'c1ccc(CSCc2ccccc2)cc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'c1ccc(CSCc2ccccc2)cc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'C(=C/c1ccccc1)\c1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CCCC(=O)CC' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'Nc1ccc(-c2ccccc2)cc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'OCCCCCO' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'Cc1ccc(C)c(N)c1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CCCCCCCCCCC=O' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CCCCCCCCCCC=O' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CCCCCCCCCCC=O' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CCCCCCCCCCC=O' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CCCC(=O)CC' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'ClCOCCl' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'C=CCCl' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'C=CCCl' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'C=CCCl' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'C=CCCl' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'C=CCCl' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=C(CC(=O)c1ccccc1)c1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'Oc1ccc2ccccc2c1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CCNCCO' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'Cc1ccc(C)c(N)c1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'Cc1ccc(C)c(N)c1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CCNCCO' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CCCC(=O)CC' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CCCC(=O)CC' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CCCC(=O)CC' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CCC(C)(C)OC' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'OCCCCCO' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'OCCCCCO' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CC(C)OC(=O)Nc1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CCCCCCCCCCCCCC=O' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# Unable to proceed the molecule 57M in task T_C_NR-ER
# mmpdb transform --smiles 'CCCCCCCCCCCCCC=O' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# Unable to proceed the molecule 58M in task T_C_NR-ER
# mmpdb transform --smiles 'Cc1ccc(N(C)C)cc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'c1ccc(B(c2ccccc2)c2ccccc2)cc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'OCCCCCO' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'Cc1cccc(C)c1[N+](=O)[O-]' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'OCCCCCO' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'Nc1ccc(S(=O)(=O)[O-])cc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'Nc1ccc(S(=O)(=O)[O-])cc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'Nc1ccc(-c2ccc(F)cc2)cc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CCCCCCCCCCl' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=c1c2ccccc2oc2ccccc12' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CN(C)c1ccc(C=O)cc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=Cc1ccc([N+](=O)[O-])cc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'Oc1ccc2ccccc2c1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CN(C)c1ccc(C=O)cc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'C[C@@H](O)C(=O)O' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'C[C@@H](O)C(=O)O' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CCC1CCC(=O)O1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'OCCCCCO' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CC(C)(C)C(=O)c1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'Cc1cccc(C)c1[N+](=O)[O-]' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'NCC(O)CC(=O)O' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=C(Nc1ccccc1)Nc1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'NNC(=O)c1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'NNC(=O)c1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'CCCCCCCOC(C)=O' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# mmpdb transform --smiles 'O=NN(O)c1ccccc1' ./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_T_C_NR-ER/data/ADMET/Generation/T_C_NR-ER_1_test.mmpdb --property value
# Task: T_C_NR-ER
# train_percentage: 89.80%
# test_percentage: 9.51%
# overlap_percentage: 0.68%
# ------------------------------------------------

# %%
import os, pickle
from rdkit import Chem
from rdkit.Chem import rdFMCS
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import rdMolDraw2D, rdDepictor

task_smiles = {'EC50_P21453_1': [['CCCc1ccc(-c2noc3c2CCc2cc(CN4CC(C(=O)O)C4)ccc2-3)cc1',
                                'CCCc1ccc(-c2noc3c2COc2cc(CN4CC(C(=O)O)C4)ccc2-3)cc1'],
                                 ['CCc1c(CCCC(=O)O)cccc1-c1nsc(-c2ccc(OC(C)C)c(C#N)c2)n1',
                                'CCc1c(CCCC(=O)O)cccc1-c1noc(-c2ccc(OC(C)C)c(C#N)c2)n1'],
                                 ['Cc1cc(-c2cnc(-c3sc(C)c4c3CC3C4C3(C)C)s2)cc(C)c1OCC(O)CO',
                                'Cc1cc(-c2cnc(-c3sc(C)c4c3CC3C4C3(C)C)o2)cc(C)c1OCC(O)CO']
                                ],
               'IC50_O43614_1': [['CCOc1ccccc1-c1noc(C2CCCN2C(=O)c2cc(F)ccc2-n2nccn2)n1',
                                'CCOc1ccccc1-c1noc(C2CCCN2C(=O)c2cc(C)ccc2-n2nccn2)n1'],
                                 ['COc1cccc(OC)c1C1CCCC(=O)N1Cc1ccnc(N2CCCC2)c1',
                                'COc1cccc(OC)c1C1CCCC(=O)N1Cc1cccc(N2CCCC2)c1'],
                                 ['CC1COc2ccc(F)cc2C(C)N1C(=O)c1ccc(Cl)cc1',
                                'Cc1ccc2c(c1)C(C)N(C(=O)c1ccc(Cl)cc1)C(C)CO2'],
                                 ['COc1cncc(OC)c1C1CCCC(=O)N1Cc1cccc(-c2csc(C)n2)c1',
                                'COc1cccc(OC)c1C1CCCC(=O)N1Cc1cccc(-c2csc(C)n2)c1'],
                                 ['Cc1ccc(-n2nccn2)c(C(=O)N2CCOCC2Cc2cccc(-n3cncn3)c2)c1',
                                'Cc1ccc(-n2nccn2)c(C(=O)N2CCOCC2Cc2cccc(-n3cccn3)c2)c1'],
                                 ['COc1cncc(OC)c1C1CCCCC(=O)N1Cc1cccc(-c2csc(C)n2)c1',
                                'COc1cccc(OC)c1C1CCCCC(=O)N1Cc1cccc(-c2csc(C)n2)c1'],
                                 ['COc1cccc(OC)c1C1CCCC(=O)N1Cc1cccc(-n2cncn2)c1',
                                'COc1cccc(OC)c1C1CCCC(=O)N1Cc1cccc(-n2cccn2)c1'],
                                 ['COc1ncnc(OC)c1C1CCCC(=O)N1Cc1cccc(-c2csc(C)n2)c1',
                                'COc1ccnc(OC)c1C1CCCC(=O)N1Cc1cccc(-c2csc(C)n2)c1'],
                                 ['CCOc1ncccc1-c1noc(C2CCCN2C(=O)c2cc(F)ccc2-n2nccn2)n1',
                                'CCOc1ncccc1-c1noc(C2CCCN2C(=O)c2cc(C)ccc2-n2nccn2)n1']
                                ], 
               'Ki_P14416_1': [['CCCN1CCC(c2coc3ccccc23)CC1',
                                'CCCN1CCC(c2csc3ccccc23)CC1'],
                                 ['CCCN(CCc1ccc(C)cc1)C1CCc2c(O)cccc2C1',
                                'CCCN(CCc1ccc(N)cc1)C1CCc2c(O)cccc2C1'],
                                 ['Cl.O=C(NCCCCN1CCN(c2cccc(Cl)c2Cl)CC1)c1cc2ccccc2o1',
                                'Cl.O=C(NCCCCN1CCN(c2cccc(Cl)c2Cl)CC1)c1cc2ccccc2s1'],
                                 ['CN1CCN(C2=Nc3ccccc3Oc3ccc(Cl)cc32)CC1',
                                'CN1CCN(C2=Nc3ccccc3Sc3ccc(Cl)cc32)CC1'],
                                 ['O=S(=O)(NCCCCN1CCN(c2noc3ccccc23)CC1)c1cccc2scnc12',
                                'O=S(=O)(NCCCCN1CCN(c2nsc3ccccc23)CC1)c1cccc2scnc12']
                                ],
              'M_C_CYP1A2_inhibitor': [
                  ['O=S(=O)(O)c1nc2ccccc2n1Cc1ccccc1', 'CS(=O)(=O)c1nc2ccccc2n1Cc1ccccc1'],
                  ['COc1cccc(C2=NOC(C(=O)NCc3ccccn3)C2)c1', 'COc1cccc(C2=NOC(C(=O)NCc3ccccc3)C2)c1']
              ],
              'M_C_CYP2C9_inhibitor': [
                  ['O=c1c(-c2ccc(F)cc2)nc2cnc(N3CCOCC3)nc2n1Cc1cccs1', 'O=c1c(-c2ccc(F)cc2)nc2cnc(N3CCNCC3)nc2n1Cc1cccs1'],
                  ['COc1cccc(Cn2c(=O)c(-c3ccc(F)cc3)nc3cnc(N4CCOCC4)nc32)c1', 'COc1cccc(Cn2c(=O)c(-c3ccc(F)cc3)nc3cnc(N4CCNCC4)nc32)c1']
              ],
              'M_C_CYP3A4_inhibitor': [
                  ['O=C(c1ccncc1)N1CCC2(CCCN(c3ccncc3)C2)CC1', 'O=C(c1ccncc1)N1CCC2(CCCN(c3ccccc3)C2)CC1'],
                  ['COCC(=O)N1CCCC2(CCN(c3ccccn3)C2)C1', 'COCC(=O)N1CCCC2(CCN(c3ccccc3)C2)C1']
              ], 
              'T_C_NR-AhR': [
                  ['Nc1ccc(-c2ccccc2)cc1', 'Oc1ccc(-c2ccccc2)cc1'],
                  ['COc1ccc(N)cc1', 'COc1ccc(C)cc1'],
                  ['Cc1ccc([N+](=O)[O-])cc1N', 'Cc1ccc([N+](=O)[O-])cc1C'],
                  ['Cc1cccc(O)c1N', 'Cc1cccc(O)c1C'],
                  ['Oc1ccccc1O', 'Cc1ccccc1O']
              ], 
              'T_C_NR-ER': [
                  ['CC(O)CN(C)C', 'CC(C)CC(C)O'],
                  ['Nc1ccc(-c2ccccc2)cc1', 'Cc1ccc(-c2ccccc2)cc1'],
                  ['Cc1ccc(N(C)C)cc1', 'Cc1ccc(C(C)C)cc1'],
                  ['C[C@@H](O)C(=O)O', 'C[C@@H](N)C(=O)O'],
                  ['OCCCCCO', 'OCCNCCO']
              ], 
              'T_C_Ames': [
                  ['Nc1ccccc1-c1ccccc1', 'Cc1ccccc1-c1ccccc1'],
                  ['Cc1ccccc1N', 'Cc1ccccc1C'],
                  ['OCCCCl', 'CCCCCl'],
                  ['CCCCOO', 'CCCCCO'],
                  ['Nc1ccc2c(c1)C(=O)c1ccccc1C2=O', 'Cc1ccc2c(c1)C(=O)c1ccccc1C2=O'],
                  ['Cc1ccc(N)c(O)c1', 'Cc1ccc(C)c(O)c1'],
                  ['CCl', 'CCS'],
                  ['C=CCNC(N)=O', 'C=CCNC(N)=S'],
                  ['Nc1cccc(N)c1', 'Cc1cccc(N)c1'],
                  ['Cc1cc(C)cc(N)c1', 'Cc1cc(C)cc(C)c1'],
                  ['c1ccc2ncccc2c1', 'c1ccc2ccccc2c1'],
                  ['CN(C)N', 'CN(C)C'],
                  ['Oc1cccc2ncccc12', 'Oc1cccc2ccccc12'],
                  ['Nc1cc(Cl)ccc1O', 'Cc1cc(Cl)ccc1O'],
                  ['C=Cc1ccc(N)cc1', 'C=Cc1ccc(C)cc1'],
                  ['CCOP(=O)(OCC)Oc1ccc([N+](=O)[O-])cc1', 'CCOP(=S)(OCC)Oc1ccc([N+](=O)[O-])cc1']
              ]
              }

for task_id, mmps in task_smiles.items():
    print(f"========================== {task_id} ==========================")
    task_novel_counter = 0
    if task_id in ['EC50_P21453_1', 'IC50_O43614_1', 'Ki_P14416_1']:
        test_filename = f'./OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_{task_id}/data/{task_id}_test.csv'
    elif task_id in ['M_C_CYP1A2_inhibitor', 'M_C_CYP2C9_inhibitor', 'M_C_CYP3A4_inhibitor']:
        test_filename = f'./OLB-AC-main/LBO-AC-Optimization/Inhibitory-Efficacy/G_ADMET_{task_id}/data/ADMET/Generation/{task_id}_1_test.csv'
    else:
        test_filename = f'./OLB-AC-main/LBO-AC-Optimization/Toxicity/G_ADMET_{task_id}/data/ADMET/Generation/{task_id}_1_test.csv'
    for idx, mmp in enumerate(mmps):
        # Define the reactant and product SMILES
        reactant_smiles, product_smiles = mmp[0], mmp[1]
        print(reactant_smiles)
        print(product_smiles)
        
        # Convert SMILES to RDKit molecules
        reactant_mol = Chem.MolFromSmiles(reactant_smiles)
        product_mol = Chem.MolFromSmiles(product_smiles)
        
        # Read test transformations
        test_count_file = os.path.join(os.path.dirname(test_filename), 'mmpdb', 'test_transformations.pkl')
        with open(test_count_file, 'rb') as f:
            test_count = pickle.load(f)
            
        # Define a list of reaction SMARTS strings or templates
        reaction_smarts = [key for key in test_count.keys()]
        
        # Convert SMARTS strings to reaction objects
        reactions = [AllChem.ReactionFromSmarts(smarts) for smarts in reaction_smarts]
        
        # Check each reaction to see if it transforms the reactant into the product
        for i, reaction in enumerate(reactions):
            products = reaction.RunReactants((reactant_mol,))
            if products:
                product = products[0][0]
                if Chem.MolToSmiles(product) == product_smiles:
                    print("Found a plausible reaction:")
                    reaction_smart = reaction_smarts[i]
                    print(reaction_smart)
                    # Read train transformations
                    train_count_file = os.path.join(os.path.dirname(test_filename), 'mmpdb', 'train_transformations.pkl')
                    with open(train_count_file, 'rb') as f:
                        train_count = pickle.load(f)
                    if train_count[reaction_smart] > 0:
                        print("This reaction can be found in the training set")
                    else:
                        task_novel_counter += 1
                        print("This reaction cannot be found in the training set")
                        # Draw the reaction
                        # Compute the invariant part (core structure)
                        reactant = reaction.GetReactantTemplate(0)
                        drawer = rdMolDraw2D.MolDraw2DSVG(-1,-1)
                        dopts = drawer.drawOptions()
                        Draw.SetACS1996Mode(dopts, 0.70)
                        dopts.bondLineWidth = 1.5 # default is 2.0
                        drawer.DrawReaction(reaction)
                        drawer.FinishDrawing()
                        
                        # Save the reaction figure
                        reaction_figure_path = f'./results/optimization/transforamtion/{task_id}/{idx}_{i}_novel_reaction.svg'
                        if not os.path.exists(os.path.dirname(reaction_figure_path)):
                            os.makedirs(os.path.dirname(reaction_figure_path))         
                        with open(reaction_figure_path, 'w') as f:
                            f.write(drawer.GetDrawingText())
                            
                        # Draw common part
                        common_part = Chem.MolFromSmarts(Chem.rdFMCS.FindMCS([reactant_mol, product_mol], completeRingsOnly=False).smartsString)
                        drawer = rdMolDraw2D.MolDraw2DSVG(-1,-1)
                        dopts = drawer.drawOptions()
                        Draw.SetACS1996Mode(dopts, 0.70)
                        dopts.bondLineWidth = 1.5 # default is 2.0
                        drawer.DrawMolecule(common_part)
                        drawer.FinishDrawing()
                        common_part_file = reaction_figure_path.replace(f'{idx}_{i}_novel_reaction.svg', f'{idx}_{i}_common_part.svg')
                        with open(common_part_file, 'w') as f:
                            f.write(drawer.GetDrawingText())

                        # Draw reactant molecule
                        drawer = rdMolDraw2D.MolDraw2DSVG(-1,-1)
                        dopts = drawer.drawOptions()
                        Draw.SetACS1996Mode(dopts, 0.70)
                        dopts.bondLineWidth = 1.5 # default is 2.0
                        drawer.DrawMolecule(reactant_mol)
                        drawer.FinishDrawing()
                        reactant_file = reaction_figure_path.replace(f'{idx}_{i}_novel_reaction.svg', f'{idx}_{i}_reactant.svg')
                        with open(reactant_file, 'w') as f:
                            f.write(drawer.GetDrawingText())

                        # Draw product molecule
                        drawer = rdMolDraw2D.MolDraw2DSVG(-1,-1)
                        dopts = drawer.drawOptions()
                        Draw.SetACS1996Mode(dopts, 0.70)
                        dopts.bondLineWidth = 1.5 # default is 2.0
                        drawer.DrawMolecule(product_mol)
                        drawer.FinishDrawing()
                        product_file = reaction_figure_path.replace(f'{idx}_{i}_novel_reaction.svg', f'{idx}_{i}_product.svg')
                        with open(product_file, 'w') as f:
                            f.write(drawer.GetDrawingText())
                    break
        else:
            print("No plausible reaction found.")
        print(f"------------------------------------------------")
    print(f'========================== {task_id}: {task_novel_counter} novel transformation are found ==========================')
# Out:
# ========================== EC50_P21453_1 ==========================
# CCCc1ccc(-c2noc3c2CCc2cc(CN4CC(C(=O)O)C4)ccc2-3)cc1
# CCCc1ccc(-c2noc3c2COc2cc(CN4CC(C(=O)O)C4)ccc2-3)cc1
# No plausible reaction found.
# ------------------------------------------------
# CCc1c(CCCC(=O)O)cccc1-c1nsc(-c2ccc(OC(C)C)c(C#N)c2)n1
# CCc1c(CCCC(=O)O)cccc1-c1noc(-c2ccc(OC(C)C)c(C#N)c2)n1
# Found a plausible reaction:
# [*:1]c1nsc([*:2])n1>>[*:1]c1noc([*:2])n1
# This reaction cannot be found in the training set
# ------------------------------------------------
# Cc1cc(-c2cnc(-c3sc(C)c4c3CC3C4C3(C)C)s2)cc(C)c1OCC(O)CO
# Cc1cc(-c2cnc(-c3sc(C)c4c3CC3C4C3(C)C)o2)cc(C)c1OCC(O)CO
# No plausible reaction found.
# ------------------------------------------------
# ========================== EC50_P21453_1: 1 novel transformation are found ==========================
# ========================== IC50_O43614_1 ==========================
# CCOc1ccccc1-c1noc(C2CCCN2C(=O)c2cc(F)ccc2-n2nccn2)n1
# CCOc1ccccc1-c1noc(C2CCCN2C(=O)c2cc(C)ccc2-n2nccn2)n1
# Found a plausible reaction:
# [*:1]c1ccc(F)cc1[*:2]>>[*:1]c1ccc(C)cc1[*:2]
# This reaction cannot be found in the training set
# ------------------------------------------------
# COc1cccc(OC)c1C1CCCC(=O)N1Cc1ccnc(N2CCCC2)c1
# COc1cccc(OC)c1C1CCCC(=O)N1Cc1cccc(N2CCCC2)c1
# Found a plausible reaction:
# [*:1]Cc1ccnc([*:2])c1>>[*:1]Cc1cccc([*:2])c1
# This reaction can be found in the training set
# ------------------------------------------------
# CC1COc2ccc(F)cc2C(C)N1C(=O)c1ccc(Cl)cc1
# Cc1ccc2c(c1)C(C)N(C(=O)c1ccc(Cl)cc1)C(C)CO2
# Found a plausible reaction:
# [*:1]c1ccc(F)cc1[*:2]>>[*:1]c1ccc(C)cc1[*:2]
# This reaction cannot be found in the training set
# ------------------------------------------------
# COc1cncc(OC)c1C1CCCC(=O)N1Cc1cccc(-c2csc(C)n2)c1
# COc1cccc(OC)c1C1CCCC(=O)N1Cc1cccc(-c2csc(C)n2)c1
# Found a plausible reaction:
# [*:1]c1c(OC)cncc1OC>>[*:1]c1c(OC)cccc1OC
# This reaction can be found in the training set
# ------------------------------------------------
# Cc1ccc(-n2nccn2)c(C(=O)N2CCOCC2Cc2cccc(-n3cncn3)c2)c1
# Cc1ccc(-n2nccn2)c(C(=O)N2CCOCC2Cc2cccc(-n3cccn3)c2)c1
# Found a plausible reaction:
# [*:1]n1cncn1>>[*:1]n1cccn1
# This reaction can be found in the training set
# ------------------------------------------------
# COc1cncc(OC)c1C1CCCCC(=O)N1Cc1cccc(-c2csc(C)n2)c1
# COc1cccc(OC)c1C1CCCCC(=O)N1Cc1cccc(-c2csc(C)n2)c1
# Found a plausible reaction:
# [*:1]c1c(OC)cncc1OC>>[*:1]c1c(OC)cccc1OC
# This reaction can be found in the training set
# ------------------------------------------------
# COc1cccc(OC)c1C1CCCC(=O)N1Cc1cccc(-n2cncn2)c1
# COc1cccc(OC)c1C1CCCC(=O)N1Cc1cccc(-n2cccn2)c1
# Found a plausible reaction:
# [*:1]n1cncn1>>[*:1]n1cccn1
# This reaction can be found in the training set
# ------------------------------------------------
# COc1ncnc(OC)c1C1CCCC(=O)N1Cc1cccc(-c2csc(C)n2)c1
# COc1ccnc(OC)c1C1CCCC(=O)N1Cc1cccc(-c2csc(C)n2)c1
# Found a plausible reaction:
# [*:1]c1c(OC)ncnc1OC>>[*:1]c1c(OC)ccnc1OC
# This reaction cannot be found in the training set
# ------------------------------------------------
# CCOc1ncccc1-c1noc(C2CCCN2C(=O)c2cc(F)ccc2-n2nccn2)n1
# CCOc1ncccc1-c1noc(C2CCCN2C(=O)c2cc(C)ccc2-n2nccn2)n1
# Found a plausible reaction:
# [*:1]c1ccc(F)cc1[*:2]>>[*:1]c1ccc(C)cc1[*:2]
# This reaction cannot be found in the training set
# ------------------------------------------------
# ========================== IC50_O43614_1: 4 novel transformation are found ==========================
# ========================== Ki_P14416_1 ==========================
# CCCN1CCC(c2coc3ccccc23)CC1
# CCCN1CCC(c2csc3ccccc23)CC1
# Found a plausible reaction:
# [*:1]c1coc2ccccc12>>[*:1]c1csc2ccccc12
# This reaction can be found in the training set
# ------------------------------------------------
# CCCN(CCc1ccc(C)cc1)C1CCc2c(O)cccc2C1
# CCCN(CCc1ccc(N)cc1)C1CCc2c(O)cccc2C1
# Found a plausible reaction:
# [*:1]c1ccccc1>>[*:1]c1ccc(N)cc1
# This reaction can be found in the training set
# ------------------------------------------------
# Cl.O=C(NCCCCN1CCN(c2cccc(Cl)c2Cl)CC1)c1cc2ccccc2o1
# Cl.O=C(NCCCCN1CCN(c2cccc(Cl)c2Cl)CC1)c1cc2ccccc2s1
# No plausible reaction found.
# ------------------------------------------------
# CN1CCN(C2=Nc3ccccc3Oc3ccc(Cl)cc32)CC1
# CN1CCN(C2=Nc3ccccc3Sc3ccc(Cl)cc32)CC1
# Found a plausible reaction:
# [*:1]O[*:2]>>[*:1]S[*:2]
# This reaction can be found in the training set
# ------------------------------------------------
# O=S(=O)(NCCCCN1CCN(c2noc3ccccc23)CC1)c1cccc2scnc12
# O=S(=O)(NCCCCN1CCN(c2nsc3ccccc23)CC1)c1cccc2scnc12
# Found a plausible reaction:
# [*:1]c1noc2ccccc12>>[*:1]c1nsc2ccccc12
# This reaction can be found in the training set
# ------------------------------------------------
# ========================== Ki_P14416_1: 0 novel transformation are found ==========================
# ========================== M_C_CYP1A2_inhibitor ==========================
# O=S(=O)(O)c1nc2ccccc2n1Cc1ccccc1
# CS(=O)(=O)c1nc2ccccc2n1Cc1ccccc1
# Found a plausible reaction:
# [*:1]S(=O)(=O)O>>[*:1]S(C)(=O)=O
# This reaction cannot be found in the training set
# ------------------------------------------------
# COc1cccc(C2=NOC(C(=O)NCc3ccccn3)C2)c1
# COc1cccc(C2=NOC(C(=O)NCc3ccccc3)C2)c1
# Found a plausible reaction:
# [*:1]c1ccccn1>>[*:1]c1ccccc1
# This reaction cannot be found in the training set
# ------------------------------------------------
# ========================== M_C_CYP1A2_inhibitor: 2 novel transformation are found ==========================
# ========================== M_C_CYP2C9_inhibitor ==========================
# O=c1c(-c2ccc(F)cc2)nc2cnc(N3CCOCC3)nc2n1Cc1cccs1
# O=c1c(-c2ccc(F)cc2)nc2cnc(N3CCNCC3)nc2n1Cc1cccs1
# Found a plausible reaction:
# [*:1]N1CCOCC1>>[*:1]N1CCNCC1
# This reaction cannot be found in the training set
# ------------------------------------------------
# COc1cccc(Cn2c(=O)c(-c3ccc(F)cc3)nc3cnc(N4CCOCC4)nc32)c1
# COc1cccc(Cn2c(=O)c(-c3ccc(F)cc3)nc3cnc(N4CCNCC4)nc32)c1
# Found a plausible reaction:
# [*:1]N1CCOCC1>>[*:1]N1CCNCC1
# This reaction cannot be found in the training set
# ------------------------------------------------
# ========================== M_C_CYP2C9_inhibitor: 2 novel transformation are found ==========================
# ========================== M_C_CYP3A4_inhibitor ==========================
# O=C(c1ccncc1)N1CCC2(CCCN(c3ccncc3)C2)CC1
# O=C(c1ccncc1)N1CCC2(CCCN(c3ccccc3)C2)CC1
# No plausible reaction found.
# ------------------------------------------------
# COCC(=O)N1CCCC2(CCN(c3ccccn3)C2)C1
# COCC(=O)N1CCCC2(CCN(c3ccccc3)C2)C1
# Found a plausible reaction:
# [*:1]c1ccccn1>>[*:1]c1ccccc1
# This reaction cannot be found in the training set
# ------------------------------------------------
# ========================== M_C_CYP3A4_inhibitor: 1 novel transformation are found ==========================
# ========================== T_C_NR-AhR ==========================
# Nc1ccc(-c2ccccc2)cc1
# Oc1ccc(-c2ccccc2)cc1
# Found a plausible reaction:
# [*:1]N>>[*:1]O
# This reaction cannot be found in the training set
# ------------------------------------------------
# COc1ccc(N)cc1
# COc1ccc(C)cc1
# Found a plausible reaction:
# [*:1]N>>[*:1]C
# This reaction cannot be found in the training set
# ------------------------------------------------
# Cc1ccc([N+](=O)[O-])cc1N
# Cc1ccc([N+](=O)[O-])cc1C
# Found a plausible reaction:
# [*:1]c1ccccc1N>>[*:1]c1ccc([N+](=O)[O-])cc1C
# This reaction cannot be found in the training set
# ------------------------------------------------
# Cc1cccc(O)c1N
# Cc1cccc(O)c1C
# Found a plausible reaction:
# [*:1]N>>[*:1]C
# This reaction cannot be found in the training set
# ------------------------------------------------
# Oc1ccccc1O
# Cc1ccccc1O
# Found a plausible reaction:
# [*:1]O>>[*:1]C
# This reaction cannot be found in the training set
# ------------------------------------------------
# ========================== T_C_NR-AhR: 5 novel transformation are found ==========================
# ========================== T_C_NR-ER ==========================
# CC(O)CN(C)C
# CC(C)CC(C)O
# Found a plausible reaction:
# [*:1]N>>[*:1]C(C)C
# This reaction can be found in the training set
# ------------------------------------------------
# Nc1ccc(-c2ccccc2)cc1
# Cc1ccc(-c2ccccc2)cc1
# Found a plausible reaction:
# [*:1]N>>[*:1]C
# This reaction can be found in the training set
# ------------------------------------------------
# Cc1ccc(N(C)C)cc1
# Cc1ccc(C(C)C)cc1
# Found a plausible reaction:
# [*:1]N>>[*:1]C(C)C
# This reaction can be found in the training set
# ------------------------------------------------
# C[C@@H](O)C(=O)O
# C[C@@H](N)C(=O)O
# Found a plausible reaction:
# [*:1]O>>[*:1]N
# This reaction can be found in the training set
# ------------------------------------------------
# OCCCCCO
# OCCNCCO
# Found a plausible reaction:
# [*:1]CCCCCO>>[*:1]CCNCCO
# This reaction cannot be found in the training set
# ------------------------------------------------
# ========================== T_C_NR-ER: 1 novel transformation are found ==========================
# ========================== T_C_Ames ==========================
# Nc1ccccc1-c1ccccc1
# Cc1ccccc1-c1ccccc1
# Found a plausible reaction:
# [*:1]c1ccccc1N>>[*:1]c1ccccc1C
# This reaction cannot be found in the training set
# ------------------------------------------------
# Cc1ccccc1N
# Cc1ccccc1C
# Found a plausible reaction:
# [*:1]c1ccccc1N>>[*:1]c1ccccc1C
# This reaction cannot be found in the training set
# ------------------------------------------------
# OCCCCl
# CCCCCl
# Found a plausible reaction:
# [*:1]CO>>[*:1]CC
# This reaction cannot be found in the training set
# ------------------------------------------------
# CCCCOO
# CCCCCO
# Found a plausible reaction:
# [*:1]C>>[*:1]CCCCO
# This reaction cannot be found in the training set
# ------------------------------------------------
# Nc1ccc2c(c1)C(=O)c1ccccc1C2=O
# Cc1ccc2c(c1)C(=O)c1ccccc1C2=O
# Found a plausible reaction:
# [*:1]c1ccc(N)cc1[*:2]>>[*:1]c1ccc(C)cc1[*:2]
# This reaction cannot be found in the training set
# ------------------------------------------------
# Cc1ccc(N)c(O)c1
# Cc1ccc(C)c(O)c1
# Found a plausible reaction:
# [*:1]c1ccc(N)c([*:2])c1>>[*:1]c1ccc(C)cc1[*:2]
# This reaction cannot be found in the training set
# ------------------------------------------------
# CCl
# CCS
# No plausible reaction found.
# ------------------------------------------------
# C=CCNC(N)=O
# C=CCNC(N)=S
# Found a plausible reaction:
# [*:1]C=O>>[*:1]C(N)=S
# This reaction can be found in the training set
# ------------------------------------------------
# Nc1cccc(N)c1
# Cc1cccc(N)c1
# Found a plausible reaction:
# [*:1]c1ccccc1>>[*:1]c1cccc(C)c1
# This reaction cannot be found in the training set
# ------------------------------------------------
# Cc1cc(C)cc(N)c1
# Cc1cc(C)cc(C)c1
# Found a plausible reaction:
# [*:1]c1cccc(N)c1>>[*:1]c1cc(C)cc(C)c1
# This reaction cannot be found in the training set
# ------------------------------------------------
# c1ccc2ncccc2c1
# c1ccc2ccccc2c1
# No plausible reaction found.
# ------------------------------------------------
# CN(C)N
# CN(C)C
# Found a plausible reaction:
# [*:1]NC>>[*:1]N(C)C
# This reaction cannot be found in the training set
# ------------------------------------------------
# Oc1cccc2ncccc12
# Oc1cccc2ccccc12
# Found a plausible reaction:
# [*:1]c1cccc2ncccc12>>[*:1]c1cccc2ccccc12
# This reaction cannot be found in the training set
# ------------------------------------------------
# Nc1cc(Cl)ccc1O
# Cc1cc(Cl)ccc1O
# Found a plausible reaction:
# [*:1]c1ccc([*:2])cc1>>[*:1]c1ccc([*:2])c(C)c1
# This reaction can be found in the training set
# ------------------------------------------------
# C=Cc1ccc(N)cc1
# C=Cc1ccc(C)cc1
# Found a plausible reaction:
# [*:1]c1ccccc1>>[*:1]c1ccc(C)cc1
# This reaction can be found in the training set
# ------------------------------------------------
# CCOP(=O)(OCC)Oc1ccc([N+](=O)[O-])cc1
# CCOP(=S)(OCC)Oc1ccc([N+](=O)[O-])cc1
# Found a plausible reaction:
# [*:1]OP(=O)(O[*:2])O[*:3]>>[*:1]OP(=S)(O[*:2])O[*:3]
# This reaction cannot be found in the training set
# ------------------------------------------------
# ========================== T_C_Ames: 11 novel transformation are found ==========================

# %%
# !mmpdb list --all ./OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_EC50_P21453_1/data/EC50_P21453_1_train.mmpdb
# Out:
#                                                 Name                                                #cmpds #rules #pairs #envs  #stats  |--------------------------------------------------- Title ----------------------------------------------------| Properties
# ./OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_EC50_P21453_1/data/EC50_P21453_1_train.mmpdb   2075  40318 405510 259236 259236  MMPs from './OLB-AC-main/LBO-AC-Optimization/Bioactivity/G_OLB-AC_EC50_P21453_1/data/EC50_P21453_1_train.fragdb' value
#       Created: 2024-05-09 15:55:52.457450
#         #compounds/property:  2075/value
#         #smiles for rules: 4891  for constants: 3570
#         Fragment options:
#           cut_smarts: [#6+0;!$(*=,#[!#6])]!@!=!#[!#0;!#1;!$([CH2]);!$([CH3][CH2])]
#           max_heavies: 100
#           max_rotatable_bonds: 10
#           method: chiral
#           num_cuts: 3
#           rotatable_smarts: [!$([NH]!@C(=O))&!D1&!$(*#*)]-&!@[!$([NH]!@C(=O))&!D1&!$(*#*)]
#           salt_remover: <default>
#         Index options:
#           max_variable_heavies: 10
#           symmetric: False

# %%
# !mmpdb list --help
# Out:
# usage: mmpdb list [-h] [--all] [--quiet] [--recount] [DATABASE ...]
#
# positional arguments:
#   DATABASE     zero or more database locations (eg, 'csd.mmpdb')
#
# optional arguments:
#   -h, --help   show this help message and exit
#   --all, -a    list all information about the dataset
#   --quiet, -q  do not show progress or status information
#   --recount    count the table sizes directly, instead of using cached data
#
# In the simplest case, look in the current directory for files matching
# '*.mmpdb', open each one, and print a terse summary of the information
# in the database.
#
#   % mmpdb list
#                Name             #cmpds  #rules  #pairs   #envs    #stats   |-------- Title ---------| Properties
#   CHEMBL_thrombin_Ki_IC50.mmpdb   2985   29513   258294   199631        0  thrombin Ki IC50
#                       csd.mmpdb  16843 2525166 15328608 15199376 15199376  MMPs from 'csd.fragments'  MP
#
# The output is a set of columns. The first line is the header. The first
# column contains the database name. The next columns contain the number
# of compounds, number of rules, number of pairs (a rule may have many
# matched molecular pairs), number of rule environments (a rule may have
# many environments), and number of property statistics for the rule
# environments. After that is the user-defined title field, followed by
# a list of the property or activity names stored.
#
# The first entry, for thrombin, has no properties, which is why it also
# has no property statistics. The second entry has a 'MP' property,
# which in this case means 'melting point'.
#
# The specific database location(s) can be given on the
# command-line. The '--all' option shows more detailed information about
# the dataset. The following gives more detailed information about the
# database 'csd.mmpdb':
#
#   % mmpdb list --all csd.mmpdb
#      Name   #cmpds  #rules  #pairs   #envs    #stats   |-------- Title --------| Properties
#   csd.mmpdb  16843 2525166 15328608 15199376 15199376  MMPs from 'csd.fragments' MP
#         Created: 2017-05-26 15:07:07.775249
#           #compounds/property:  16843/MP
#           #smiles for rules: 81538  for constants: 21520
#           Fragment options:
#             cut_smarts: [#6+0;!$(*=,#[!#6])]!@!=!#[!#0;!#1;!$([CH2]);!$([CH3][CH2])]
#             max_heavies: 100
#             max_rotatable_bonds: 10
#             method: chiral
#             num_cuts: 3
#             rotatable_smarts: [!$([NH]!@C(=O))&!D1&!$(*#*)]-&!@[!$([NH]!@C(=O))&!D1&!$(*#*)]
#             salt_remover: <default>
#           Index options:
#             max_variable_heavies: 10
#             symmetric: False
#
# 'Created' shows the creation time. '#compounds/property' shows how
# many compounds have a given property, for each of the available
# properties. The '#smiles' line says how many distinct SMILES strings
# are used for the rules and the constants tables. 'Fragment options'
# and 'Index options' are, I think, self-explanatory.
#
# The count fields (like the number of compounds and rules) are
# pre-computed and stored in the database. If the database is updated
# incorrectly, it is possible for the cached information to be
# invalid. Use '--recount' to have SQLite compute the values directly
# from the database contents.

# %%
# !mmpdb help-analysis
# Out:
# The overall process is:
#
#   1) Fragment structures in a SMILES file, to produce fragments.
#
#   2) Index the fragments to produces matched molecular pairs.
#      (you might include property information at this point)
#
#   3) Load property information.
#
#   4) Find transforms for a given structure; and/or
#
#   5) Predict a property for a structure given the known
#      property for another structure
#
# Some terminology:
# A fragmentation cuts 1, 2, or 3 non-ring bonds to
# convert a structure into a "constant" part and a "variable" part. The
# substructure in the variable part is a single fragment, and often
# considered the R-groups, while the constant part contains one
# fragment for each cut, and it often considered as containing the
# core.
#
# The matched molecular pair indexing process finds all pairs which have
# the same constant part, in order to define a transformation from one
# variable part to another variable part. A "rule" stores information
# about a transformation, including a list of all the pairs for that
# rule.
#
# The "rule environment" extends the transformation to include
# information about the local environment of the attachment points on
# the constant part. The environment fingerprint is based on the RDKit
# circular fingerprints for the attachment points. There is one rule
# environment for each available radius. Larger radii correspond to more
# specific environments. The "rule environment statistics" table stores
# information about the distribution of property changes for all of the
# pairs which contain the given rule and environment, with one table
# for each property.
#
#
#
# #### 1) Fragment structures
#
#
# Use "`smifrag`" to see how a given SMILES is fragmented. Use "`fragment`"
# to fragment all of the compounds in a SMILES file.
#
# "`mmpdb smifrag`" is a diagnostic tool to help understand how a given
# SMILES will be fragmented and to experiment with the different
# fragmentation options. For example:
#
# ```shell
#   % mmpdb smifrag 'c1ccccc1OC'
#                      |-------------  variable  -------------|       |---------------------  constant  --------------------
#   #cuts | enum.label | #heavies | symm.class | smiles       | order | #heavies | symm.class | smiles           | with-H
#   ------+------------+----------+------------+--------------+-------+----------+------------+------------------+----------
#     1   |     N      |    2     |      1     | [*]OC        |    0  |    6     |      1     | [*]c1ccccc1      | c1ccccc1
#     1   |     N      |    6     |      1     | [*]c1ccccc1  |    0  |    2     |      1     | [*]OC            | CO
#     2   |     N      |    1     |     11     | [*]O[*]      |   01  |    7     |     12     | [*]C.[*]c1ccccc1 | -
#     1   |     N      |    1     |      1     | [*]C         |    0  |    7     |      1     | [*]Oc1ccccc1     | Oc1ccccc1
#     1   |     N      |    7     |      1     | [*]Oc1ccccc1 |    0  |    1     |      1     | [*]C             | C
# ```
#
# Use "`mmpdb fragment`" to fragment a SMILES file and produce a fragment
# file for the MMP analysis. Start with the test data file named
# "test_data.smi" containing the following structures:
#
# Oc1ccccc1 phenol
# Oc1ccccc1O catechol
# Oc1ccccc1N 2-aminophenol
# Oc1ccccc1Cl 2-chlorophenol
# Nc1ccccc1N o-phenylenediamine
# Nc1cc(O)ccc1N amidol
# Oc1cc(O)ccc1O hydroxyquinol
# Nc1ccccc1 phenylamine
# C1CCCC1N cyclopentanol
#
# ```shell
#   % mmpdb fragment test_data.smi -o test_data.fragments
# ```
# Fragmentation can take a while. You can save time by asking the code
# to reuse fragmentations from a previous run. If you do that then the
# fragment command will reuse the old fragmentation parameters. (You
# cannot override them with command-line options.). Here is an example:
#
# ```shell
#   % mmpdb fragment data_file.smi -o new_data_file.fragments          --cache old_data_file.fragments
# ```
#
# The "`--cache`" option will greatly improve the fragment performance when
# there are only a few changes from the previous run.
#
# The fragmentation algorithm is configured to ignore structures which
# are too big or have too many rotatable bonds. There are also options
# which change where to make cuts and the number of cuts to make. Use
# the "`--help`" option on each command for details.
#
# Use "`mmpdb help-smiles-format`" for details about to parse different
# variants of the SMILES file format.
#
#
#
# #### 2) Index the MMPA fragments to create a database
#
#
# The "`mmpa index`" command indexes the output fragments from "`mmpa
# fragment`" by their variable fragments, that is, it finds
# fragmentations with the same R-groups and puts them together. Here's
# an example:
#
# ```shell
#   % mmpdb index test_data.fragments -o test_data.mmpdb
# ```
# The output from this is a SQLite database.
#
# If you have activity/property data and you do not want the database to
# include structures where there is no data, then you can specify
# the properties file as well:
#
# ```shell
#   % mmpdb index test_data.fragments -o test_data.mmpa --properties test_data.csv
# ```
# Use "`mmpdb help-property-format`" for property file format details.
#
# For more help use "`mmpdb index --help`".
#
#
#
# #### 3) Add properties to a database
#
#
# Use "`mmpdb loadprops`" to add or modify activity/property data in the
# database. Here's an example property file named 'test_data.csv' with
# molecular weight and melting point properties:
#
# ID      MW      MP
# phenol  94.1    41
# catechol        110.1   105
# 2-aminophenol   109.1   174
# 2-chlorophenol  128.6   8
# o-phenylenediamine      108.1   102
# amidol  124.1   *
# hydroxyquinol   126.1   140
# phenylamine     93.1    -6
# cyclopentanol   86.1    -19
#
# The following loads the property data to the MMPDB database file
# created in the previous section:
#
# ```shell
#   % mmpdb loadprops -p test_data.csv test_data.mmpdb
# ```
#
# Use "`mmpdb help-property-format`" for property file format details.
#
# For more help use "`mmpdb loadprops --help`". Use "`mmpdb list`" to see
# what properties are already loaded.
#
#
#
# #### 4) Identify possible transforms
#
#
# Use "`mmpdb transform`" to transform an input structure using the rules
# in a database. For each transformation, it can estimate the effect on
# any properties. The following looks at possible ways to transform
# 2-pyridone using the test dataset created in the previous section, and
# predict the effect on the "MW" property (the output is reformatted for
# clarity):
#
# ```shell
#   % mmpdb transform --smiles 'c1cccnc1O' test_data.mmpdb --property MW
#   ID      SMILES MW_from_smiles MW_to_smiles  MW_radius  \
#    1  Clc1ccccn1         [*:1]O      [*:1]Cl          1
#    2   Nc1ccccn1         [*:1]O       [*:1]N          1
#    3    c1ccncc1         [*:1]O     [*:1][H]          1
#
#                                MW_fingerprint  MW_rule_environment_id  \
#   tLP3hvftAkp3EUY+MHSruGd0iZ/pu5nwnEwNA+NiAh8                     298
#   tLP3hvftAkp3EUY+MHSruGd0iZ/pu5nwnEwNA+NiAh8                     275
#   tLP3hvftAkp3EUY+MHSruGd0iZ/pu5nwnEwNA+NiAh8                     267
#
#   MW_count  MW_avg  MW_std  MW_kurtosis  MW_skewness  MW_min  MW_q1  \
#          1    18.5     NaN          NaN          NaN    18.5   18.5
#          3    -1.0     0.0          NaN          0.0    -1.0   -1.0
#          4   -16.0     0.0          NaN          0.0   -16.0  -16.0
#
#   MW_median  MW_q3  MW_max  MW_paired_t  MW_p_value
#        18.5   18.5    18.5          NaN         NaN
#        -1.0   -1.0    -1.0  100000000.0         NaN
#       -16.0  -16.0   -16.0  100000000.0         NaN
# ```
#
# This says that "c1cccnc1O" can be transformed to "Clc1ccccn1" using
# the transformation \[\*:1\]O>>\[\*:1\]Cl (that is, replace the oxygen with a
# chlorine). The best transformation match has a radius of 1, which
# includes the aromatic carbon at the attachment point but not the
# aromatic nitrogen which is one atom away.
#
# There is only one pair for this transformation, and it predicts a shift
# in molecular weight of 18.5. This makes sense as the [OH] is replaced
# with a [Cl].
#
# On the other hand, there are three pairs which transform it to
# pyridine. The standard deviation of course is 0 because it's a simple
# molecular weight calculation. The 100000000.0 is the mmpdb way of
# writing "positive infinity".
#
# Melting point is more complicated. The following shows that in the
# transformation of 2-pyridone to pyridine there are still 3 matched
# pairs and in this case the average shift is -93C with a standard
# deviation of 76.727C:
#
# ```shell
#   % mmpdb transform --smiles 'c1cccnc1O' test_data.mmpdb --property MP
#   ID      SMILES MP_from_smiles MP_to_smiles  MP_radius  \
#   1  Clc1ccccn1         [*:1]O      [*:1]Cl          1
#   2   Nc1ccccn1         [*:1]O       [*:1]N          1
#   3    c1ccncc1         [*:1]O     [*:1][H]          1
#
#                                MP_fingerprint  MP_rule_environment_id  \
#  tLP3hvftAkp3EUY+MHSruGd0iZ/pu5nwnEwNA+NiAh8                     298
#  tLP3hvftAkp3EUY+MHSruGd0iZ/pu5nwnEwNA+NiAh8                     275
#  tLP3hvftAkp3EUY+MHSruGd0iZ/pu5nwnEwNA+NiAh8                     267
#
#   MP_count  MP_avg  MP_std  MP_kurtosis  MP_skewness  MP_min   MP_q1  \
#         1 -97.000     NaN          NaN          NaN     -97  -97.00
#         3 -16.667  75.235         -1.5     -0.33764     -72  -65.75
#         3 -93.000  76.727         -1.5      0.32397    -180 -151.00
#
#   MP_median  MP_q3  MP_max  MP_paired_t  MP_p_value
#        -97 -97.00     -97          NaN         NaN
#        -47  40.00      69       0.3837     0.73815
#        -64 -42.25     -35       2.0994     0.17062
# ```
#
# You might try enabling the "`--explain`" option to see why the algorithm
# selected a given tranformation.
#
# For more help use "`mmpdb transform --help`".
#
#
#
# #### 5) Use MMP to make a prediction
#
#
# Use "`mmpdb predict`" to predict the property change in a transformation
# from a given reference structure to a given query structure. Use this
# when you want to limit the transform results when you know the
# starting and ending structures. The following predicts the effect on
# molecular weight in transforming 2-pyridone to pyridone:
#
# ```shell
#   % mmpdb predict --smiles 'c1cccnc1' --reference 'c1cccnc1O' \
#             test_data.mmpdb --property MP
#   predicted delta: -93 +/- 76.7268
# ```
#
# This is the same MP_value and MP_std from the previous section using
# '`transform`'.
#
# ```shell
#   % mmpdb predict --smiles 'c1cccnc1' --reference 'c1cccnc1O' \
#             test_data.mmpdb --property MP --value -41.6
# ```
#
# I'll redo the calculation with the molecular weight property, and have
# mmpdb do the trival calculation of adding the known weight to the
# predicted delta:
#
# ```shell
#   % mmpdb predict --smiles 'c1cccnc1' --reference 'c1cccnc1O' \
#             test_data.mmpdb --property MW --value 95.1
#   predicted delta: -16 predicted value: 79.1 +/- 0
# ```
#
# You might try enabling the "`--explain`" option to see why the algorithm
# selected a given transformation, or use "`--save-details`" to save the
# list of possible rules to the file 'pred_detail_rules.txt' and to save
# the list of rule pairs to "pred_detail_pairs.txt".
